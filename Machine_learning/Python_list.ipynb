# %% [markdown]
# Create an empty list and add 5 numbers using append()

# %%
numbers=[]
numbers.append(10)
numbers.append(20)
numbers.append(5)
numbers.append(14)
numbers.append(1)

# %%
print(numbers)
# Out:
# [10, 20, 5, 14, 1]

# %% [markdown]
# Insert a value at index 2 using insert().

# %%
numbers.insert(2,57)

# %%
print(numbers)
# Out:
# [10, 20, 57, 5, 14, 1]

# %%
whole=[1,2,3]

# %% [markdown]
# Add multiple elements from another list using extend().

# %%
print(whole)
# Out:
# [1, 2, 3]

# %%
numbers.extend(whole)

# %%
print(numbers)
# Out:
# [10, 20, 57, 5, 14, 1, 1, 2, 3]

# %% [markdown]
# Add a list inside another list using append() and observe the difference from extend().

# %%
numbers.append(whole)

# %%
print(numbers)
# Out:
# [10, 20, 57, 5, 14, 1, 1, 2, 3, [1, 2, 3]]

# %% [markdown]
# Removing Elements (Methods Only)
#
# Remove a specific value using remove()

# %%
numbers.remove(1)

# %%
print(numbers)
# Out:
# [10, 20, 57, 5, 14, 2, 3, [1, 2, 3]]

# %% [markdown]
# Remove and return the last element using pop().

# %%
numbers=[10, 20, 57, 5, 14, 2, 3, [1, 2, 3]]
numbers.pop()
# Out:
# [1, 2, 3]

# %%
print(numbers)
# Out:
# [10, 20, 57, 5, 14, 2, 3]

# %% [markdown]
# Remove an element at index 3 using pop().

# %%
numbers.pop(3)

print(numbers)
# Out:
# [10, 20, 57, 14, 2, 3]

# %% [markdown]
# Remove all elements from a list using clear().

# %%
numbers.clear()

print(numbers)
# Out:
# []

# %% [markdown]
#  Searching & Counting (Methods Only)
#
# Count how many times a number appears using count().

# %%
numbers=[10, 20, 57, 14, 2, 3]
print(numbers.count(10))
# Out:
# 1

# %% [markdown]
# Find the index of a specific element using index().

# %%
print(numbers.index(57))
# Out:
# 2

# %% [markdown]
# What happens if index() is used for a value not present in the list?

# %%
numbers=[10, 20, 57, 14, 2, 3]
print(numbers.index(13))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6666/4291681820.py in <cell line: 0>()
#       1 numbers=[10, 20, 57, 14, 2, 3]
# ----> 2 print(numbers.index(13))
#
# ValueError: 13 is not in list

# %% [markdown]
#  Ordering Methods
#
# Sort a list in ascending order using sort().

# %%
numbers.sort()

print(numbers)
# Out:
# [2, 3, 10, 14, 20, 57]

# %% [markdown]
# Sort a list in descending order using sort().

# %%
numbers.sort(reverse=True)

print(numbers)
# Out:
# [57, 20, 14, 10, 3, 2]

# %% [markdown]
# Reverse a list using reverse().

# %%
numbers.reverse()

print(numbers)
# Out:
# [2, 3, 10, 14, 20, 57]

# %%
numbers=[3,7,1,6,0]
numbers.reverse()

print(numbers)
# Out:
# [0, 6, 1, 7, 3]

# %% [markdown]
# Copy a list using copy() and modify the copied list.

# %%
list1 = [10, 20, 30]

list2 = list1.copy()
print(list1)
print(list2)
# Out:
# [10, 20, 30]
# [10, 20, 30]

# %%
list2 = list1.copy()
list2.append(40)
print(list2)
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# Create a list of numbers and remove duplicates using only methods

# %%
numbers=[3,7,1,7,6,0]
unique = []
for i in numbers:
    if i not in unique:
        unique.append(i)
print(unique)
# Out:
# [3, 7, 1, 6, 0]

# %% [markdown]
# Combine two lists using only list methods.

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]
list1.extend(list2)
print(list1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Replace an element at index 2 using a method.

# %%
numbers = [3, 7, 1, 6, 0]
numbers.pop(2)
numbers.insert(2, 99)
print(numbers)
# Out:
# [3, 7, 99, 6, 0]

# %% [markdown]
# Find how many times the largest element appears using methods only.

# %%
numbers=[2,6,4,9,10]
largest = max(numbers)
print(numbers.count(largest))
# Out:
# 1

# %% [markdown]
# Create a list of words and sort them alphabetically using a method.

# %%
words = ["banana", "apple","grapes",]
words.sort()
print(words)
# Out:
# ['apple', 'banana', 'grapes']
